# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# Load data from Excel file
data = pd.read_excel('train_data_restructured.xlsx')
dataTest = pd.read_excel('testing_data.xlsx')

# Separate target variable (output) and input variables
X = data.iloc[:, 1:]  # Input variables (columns from 1 to end)
y = data.iloc[:, 0]   # Target variable (first column)

# Split the data into train and test sets (80% train, 20% test)
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=0)
X_train = data.iloc[:, 1:]
y_train = data.iloc[:, 0]
X_test = dataTest.iloc[:, 1:]
y_test = dataTest.iloc[:, 0]
# Initialize the logistic regression model
model = LogisticRegression()
# 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
# Train the model on the training data
model.fit(X_train, y_train)

# Predict on the test data
y_pred = model.predict(X_test)
# print(y_pred)
# Calculate accuracy of the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy of the Logistic Regression model: {accuracy:.2f}")
# Out:
# Accuracy of the Logistic Regression model: 0.42

# %%
data.describe()
# Out:
#        (Backache NOS) or (back pain [& low])  \
# count                            1770.000000
# mean                                0.001130
# std                                 0.033605
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
#        (Bathing cramps - immersion) or (immersion)  \
# count                                  1770.000000
# mean                                      0.000565
# std                                       0.023769
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       0.000000
# max                                       1.000000
#
#        (Chronic rhinitis) or (catarrh unspecified)  \
# count                                  1770.000000
# mean                                      0.000565
# std                                       0.023769
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       0.000000
# 75%                                       0.000000
# max                                       1.000000
#
#        (Esophoria) or (strabismus NOS) or (ophthalmoplegia NOS)  \
# count                                        1770.000000
# mean                                            0.001130
# std                                             0.033605
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        (Functional constipation) or (impacted faeces)  \
# count                                     1770.000000
# mean                                         0.000565
# std                                          0.023769
# min                                          0.000000
# 25%                                          0.000000
# 50%                                          0.000000
# 75%                                          0.000000
# max                                          1.000000
#
#        (Functional constipation) or (impacted feces)  \
# count                                         1770.0
# mean                                             0.0
# std                                              0.0
# min                                              0.0
# 25%                                              0.0
# 50%                                              0.0
# 75%                                              0.0
# max                                              0.0
#
#        (Leukorrhea unspecified) or (vaginal discharge NOS)  \
# count                                        1770.000000
# mean                                            0.000565
# std                                             0.023769
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        (Leukorrhoea unspecified) or (vaginal discharge NOS)  \
# count                                             1770.0
# mean                                                 0.0
# std                                                  0.0
# min                                                  0.0
# 25%                                                  0.0
# 50%                                                  0.0
# 75%                                                  0.0
# max                                                  0.0
#
#        (Other back symptoms) or (facet joint syndrome)  \
# count                                      1770.000000
# mean                                          0.000565
# std                                           0.023769
# min                                           0.000000
# 25%                                           0.000000
# 50%                                           0.000000
# 75%                                           0.000000
# max                                           1.000000
#
#        (Other joint symptoms of the pelvic region and thigh) or (hip snapping) or (irritable hip)  \
# count                                        1770.000000
# mean                                            0.000565
# std                                             0.023769
# min                                             0.000000
# 25%                                             0.000000
# 50%                                             0.000000
# 75%                                             0.000000
# max                                             1.000000
#
#        ...  [D]Swelling, mass or lump of chest NOS  \
# count  ...                             1770.000000
# mean   ...                                0.000565
# std    ...                                0.023769
# min    ...                                0.000000
# 25%    ...                                0.000000
# 50%    ...                                0.000000
# 75%    ...                                0.000000
# max    ...                                1.000000
#
#        [D]Urinary system symptoms  [D]Urinary system symptoms NOS  \
# count                      1770.0                     1770.000000
# mean                          0.0                        0.000565
# std                           0.0                        0.023769
# min                           0.0                        0.000000
# 25%                           0.0                        0.000000
# 50%                           0.0                        0.000000
# 75%                           0.0                        0.000000
# max                           0.0                        1.000000
#
#        [D]Weight, failure to gain, infant  \
# count                         1770.000000
# mean                             0.000565
# std                              0.023769
# min                              0.000000
# 25%                              0.000000
# 50%                              0.000000
# 75%                              0.000000
# max                              1.000000
#
#        [D]Widespread diabetic foot gangrene  \
# count                           1770.000000
# mean                               0.000565
# std                                0.023769
# min                                0.000000
# 25%                                0.000000
# 50%                                0.000000
# 75%                                0.000000
# max                                1.000000
#
#        [X]Other and unspecified symbolic dysfunctions  [X]Other chest pain  \
# count                                      1770.00000          1770.000000
# mean                                          0.00339             0.000565
# std                                           0.05814             0.023769
# min                                           0.00000             0.000000
# 25%                                           0.00000             0.000000
# 50%                                           0.00000             0.000000
# 75%                                           0.00000             0.000000
# max                                           1.00000             1.000000
#
#        [X]Other chronic pain  [X]Other forms of angina pectoris  \
# count            1770.000000                        1770.000000
# mean                0.000565                           0.007910
# std                 0.023769                           0.088609
# min                 0.000000                           0.000000
# 25%                 0.000000                           0.000000
# 50%                 0.000000                           0.000000
# 75%                 0.000000                           0.000000
# max                 1.000000                           1.000000
#
#        [X]Other signs and symptoms in breast
# count                            1770.000000
# mean                                0.001130
# std                                 0.033605
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 0.000000
# 75%                                 0.000000
# max                                 1.000000
#
# [8 rows x 841 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1770 entries, 0 to 1769
# Columns: 842 entries, Disease to [X]Other signs and symptoms in breast
# dtypes: int64(841), object(1)
# memory usage: 11.4+ MB
